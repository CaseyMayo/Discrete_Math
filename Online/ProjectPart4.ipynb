# %% [markdown]
# <a href="https://colab.research.google.com/github/CaseyMayo/Discrete_Math/blob/master/Online/ProjectPart4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 4: CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Counting
#
# ### Casey Mayo

# %% [markdown]
# I did cards last week, so I will continue to do cards!
#
# I already have all the cool graphics I downloaded for cards anyway.

# %% [markdown]
# ![playing-cards-4742643_640.png](data:image/png;base64,...)

# %% [markdown]
# The possible outcomes of drawing a random card can be catergorized by suits!

# %%
possibleDraw = ['Hearts','Spades','Diamonds','Clubs'] #The possible draws listed

# %% [markdown]
# ## 1 Counting

# %% [markdown]
# There are ***FOUR*** options in my sequence of ten so there are $4^{10}$ options!
#
# For each of the ten cards that I will draw, I will have a total of 4 different possibilities!
#
# $$ 4*4*4\dots *4 = 4^{10} $$

# %% [markdown]
# ![student-7036660_640.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Stay with me here, guys!

# %% [markdown]
# So exactly how many outcomes were possible in out simulation if it is considered a sequence in that particular order?
#
# $drum$  $roll$  $please$

# %%
4**10   #The total possibilities are 1048576!
# Out:
# 1048576

# %% [markdown]
# I should have saved the cool math graphic for this one.... because when order doesn't matter and there is replacement, we get to start with the formula below.. but then $flip$ our thinking.
#
# $$
# \binom{n+k-1}{k-1} = \binom{n+k-1}{n}
# $$
#
# We still have 10 objects with 4 categories.

# %% [markdown]
# ![banner-982162_640.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Thought I was out of cool graphics?
#
# You thought wrong.

# %%
import math

math.factorial(13)/(math.factorial(10)*math.factorial(3))
# I used 13 because 4(n)+10(k)-1 = 13.
# I used 10.. the amount of placement spots. 
# I used 3... honestly because 4-1=3.
# Out:
# 286.0

# %% [markdown]
# Our possibilities went from a whopping 1048576 to a measly 286!
#
# Should we try to list them out?

# %%
from itertools import combinations_with_replacement

print(list(combinations_with_replacement(possibleDraw,10)))
# Out:
# [('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Spades'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Diamonds'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Clubs'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Spades', 'Spades'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Spades', 'Diamonds'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Spades', 'Clubs'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Diamonds', 'Diamonds'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Diamonds', 'Clubs'), ('Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', 'Hearts', '
# ...

# %% [markdown]
# I do like how the list comes out. All hearts, then a spade. All hearts, then a diamond, etc.

# %% [markdown]
# ![hand-998957_640.png](data:image/png;base64,...)

# %%
len(list(combinations_with_replacement(possibleDraw,10))) #Checking how many it actually listed.
# Out:
# 286

# %% [markdown]
# The amount of possibilities is CORRECT!

# %% [markdown]
# ## Now without replacement!

# %% [markdown]
# I only have $four$ different suits to choose from. I can't choose 10 cards and have no replacements when I only have 4 options.
#
# So let's do 4.
#
# If order matters it is $4$ and if not $\binom44$.

# %%
print(math.factorial(4))
# Out:
# 24

# %% [markdown]
# We have 24 posibilties.
#
# Remember. It's all about $order$.

# %% [markdown]
# ![cards-7093511_640.png](data:image/png;base64,...)

# %%
from itertools import permutations
print(list(permutations(possibleDraw,4)))
# Out:
# [('Hearts', 'Spades', 'Diamonds', 'Clubs'), ('Hearts', 'Spades', 'Clubs', 'Diamonds'), ('Hearts', 'Diamonds', 'Spades', 'Clubs'), ('Hearts', 'Diamonds', 'Clubs', 'Spades'), ('Hearts', 'Clubs', 'Spades', 'Diamonds'), ('Hearts', 'Clubs', 'Diamonds', 'Spades'), ('Spades', 'Hearts', 'Diamonds', 'Clubs'), ('Spades', 'Hearts', 'Clubs', 'Diamonds'), ('Spades', 'Diamonds', 'Hearts', 'Clubs'), ('Spades', 'Diamonds', 'Clubs', 'Hearts'), ('Spades', 'Clubs', 'Hearts', 'Diamonds'), ('Spades', 'Clubs', 'Diamonds', 'Hearts'), ('Diamonds', 'Hearts', 'Spades', 'Clubs'), ('Diamonds', 'Hearts', 'Clubs', 'Spades'), ('Diamonds', 'Spades', 'Hearts', 'Clubs'), ('Diamonds', 'Spades', 'Clubs', 'Hearts'), ('Diamonds', 'Clubs', 'Hearts', 'Spades'), ('Diamonds', 'Clubs', 'Spades', 'Hearts'), ('Clubs', 'Hearts', 'Spades', 'Diamonds'), ('Clubs', 'Hearts', 'Diamonds', 'Spades'), ('Clubs', 'Spades', 'Hearts', 'Diamonds'), ('Clubs', 'Spades', 'Diamonds', 'Hearts'), ('Clubs', 'Diamonds', 'Hearts', 'Spades'), ('Clubs'
# ...

# %% [markdown]
# If order doesn't matter?

# %% [markdown]
# ![pay-1036470_640.jpg](data:image/jpeg;base64,...)

# %%
math.factorial(4)/(math.factorial(0)*math.factorial(4))
# Out:
# 1.0

# %% [markdown]
# The answer is 1. Order doesn't matter. It's choosing 4 cards out of four different suits.

# %%
from itertools import combinations
print(list(combinations(possibleDraw,4)))
# Out:
# [('Hearts', 'Spades', 'Diamonds', 'Clubs')]

# %% [markdown]
# ## The Last Question

# %% [markdown]
# What is the coefficient of the 5th order of (x-3)^9?

# %% [markdown]
# So lets take 9C4, which equals... I'm not sure how to do this python wise.
#
# 9!
#
# 4!5!
#
# which equals (6x7x8x9)/(1x2x3x4)

# %% [markdown]
# ![book-4126483_640.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ***126***
