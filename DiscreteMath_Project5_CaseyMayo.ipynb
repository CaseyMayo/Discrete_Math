# %% [markdown]
# <a href="https://colab.research.google.com/github/CaseyMayo/Discrete_Math/blob/master/DiscreteMath_Project5_CaseyMayo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 5: CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Structures
#
# ### Casey Mayo

# %% [markdown]
# # Disclaimer!
#
# If I am to tell a story about my life... I am going to tell a story in a fashion that is true to me. Disorganized, flabbergasting, a little idiotic but a wild and hilarious ride. The following story is embarassing and 100% true.

# %%
import graphviz

# %% [markdown]
# Please see the below graph.
#
# I'm talking about Tornadoes, Tasers, and Girl Scouts.
#
# Buckle up.

# %% [markdown]
# ![fasten-seat-belt-98607_640.png](data:image/png;base64,...)

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')
dot.node('B', 'Girl Scouts')
dot.node('C', 'Leader and Home Owner')
dot.node('D', 'Storm Shelter')
dot.node('E', 'Tornado')
dot.node('F', 'Dark')
dot.node('G', 'Taser')
dot.node('H', 'Poker')
dot.node('I', 'Mom')
dot.node('J', 'Christmas')

dot.edges(['AB', 'BC', 'IC', 'CD', 'DE', 'AF', 'DF', 'JH', 'HG', 'HI', 'IG', 'GE'])
dot

dot

# %% [markdown]
# ## It all started with $Aby$ -- $The$ $Child$.

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')

dot

# %% [markdown]
# See, Aby was in Girl Scouts.
#
# ![Aby Young.jpg](data:image/jpeg;base64,...)

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')
dot.node('B', 'Girl Scouts')

dot.edge('A', 'B')
dot

# %% [markdown]
# I was a Girl Scout leader, and so was my mom!
#
# (Grandma likes to be overly involved, but shes my bestie so I let her)

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')
dot.node('B', 'Girl Scouts')
dot.node('C', 'Leader and Home Owner')
dot.node('I', 'Mom')


dot.edges(['AB', 'BC', 'IC'])
dot

# %% [markdown]
# ***But Casey - Where are we getting $Tasers$ and $Tornados$ from?***

# %% [markdown]
# ![fantasy-5103702_640.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Well, as a Home Owner in our great state of Oklahoma (my mom. I'm not THAT much of an adult), we know tornados are a thing. Which is why storm shelters are an amazing purchase!

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')
dot.node('B', 'Girl Scouts')
dot.node('C', 'Leader and Home Owner')
dot.node('I', 'Mom')
dot.node('D', 'Storm Shelter')
dot.node('E', 'Tornado')


dot.edges(['AB', 'BC', 'IC', 'CD', 'DE'])
dot

# %% [markdown]
# I should also mention Aby is scared of the dark, which storm shelters usually are.

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')
dot.node('B', 'Girl Scouts')
dot.node('C', 'Leader and Home Owner')
dot.node('I', 'Mom')
dot.node('D', 'Storm Shelter')
dot.node('E', 'Tornado')
dot.node('F', 'Dark')


dot.edges(['AB', 'BC', 'IC', 'CD', 'DE', 'AF', 'DF'])
dot

# %% [markdown]
# ##The Taser

# %% [markdown]
# ![taser.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# So as I side gig, I deal poker for private parties.
#
# A lot of these gigs are late at night and commonly have me walking back to my car late at night because parking in Bricktown in OKC is ***terrible.***
#
# My mother (AKA Overly involved Grandma, AKA the Bestie AKA Fam CEO) actually got me a taser one year for Christmas!

# %% [markdown]
# ![christmas-tree-2999722_640.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# So now we can add in the Verticies: Christmas, Poker, and Taser!

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')
dot.node('B', 'Girl Scouts')
dot.node('C', 'Leader and Home Owner')
dot.node('I', 'Mom')
dot.node('D', 'Storm Shelter')
dot.node('E', 'Tornado')
dot.node('F', 'Dark')
dot.node('G', 'Taser')
dot.node('H', 'Poker')
dot.node('J', 'Christmas')


dot.edges(['AB', 'BC', 'IC', 'CD', 'DE', 'AF', 'DF', 'JH', 'HG', 'HI', 'IG'])
dot

# %% [markdown]
# Back to the Scouts!
#
# ![girl scouts.png](data:image/png;base64,...)

# %% [markdown]
# It was time to lead my Troop of girls to gain thier camping badges! As a strong, independent woman.. we were holding this campout in style.. at my house. I don't do bugs.
#
# ![camping gs.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# When all of a sudden.....

# %% [markdown]
# ![windmill-7021868_640.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# The sirens go off!
#
# I place all the small children in the storm shelter and set up shop like a true Oklahoman to watch it.
#
# Kids are safe. Where is my lawn chair?

# %% [markdown]
# ![tornado.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# But I am disturbed by the whines coming from the shelter.
#
# It's dark. Kids are scared.
#
# I'm only truly a 1/2 of an adult. I don't have a flash light.
#
# ...
#
# And then I get an idea.
#
# ![light bulb.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# # **MY TASER DOUBLES AS A FLASHLIGHT!!!**

# %% [markdown]
# I run out to my car to grab the taser. I can feel the tornado breathing down my neck as the wind behind me whips it back from the sheer speed I am traveling.
#
# ![fast run.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# I fling open my cars door, and run my hands through the uneeded recipets I have stockpiled in my center console.
#
# My finger nails graze old pens and dirty change.. until.. I feel it.
#
# ![my precious.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# I have found... ***The Taser***
#
# I am halfway back to the children, my eyes constantly scanning the horizon for George (I named the tornado). He's huge. He's lightening fast. I'm watching for him with held breath while I continue through my tough travels.
#
# I've nearly reached the waiting children.. my wards, my charges.. The sirens are screaming all around us, warning to seek shelter. I go to turn on the taser's flashlight and...
#
# ![buttons.jfif](data:image/jpeg;base64,...)
#
# Which button was it again?!

# %% [markdown]
# The air bares cold breath that starts to bite my skin.
#
# I know George is near.
#
# I make a decision. I push a button.
#
# ![click button.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# ![taser lit up.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# Electricity crackles infront of me.
#
# A bright arc lights between the metal arms.
#
# My eyes go wide in the light's reflection and the '1/2 adult' part of myself kicks in to tranform my face.
#
# ![Did I really almost give a taser to a group of children.jfif](data:image/jpeg;base64,...)
#
#
#
# I was seriously about to hand this to little kids? The %&#!

# %% [markdown]
# I quickly sheath the weapon in my pocket before George gets wind of my weakened idea.
#
# $Suddenly$
#
# I am on my knees. Tears streaming down my face.
#
# This is ***it***. George has me in his grasp.
#
# White.
#
# Blinding.
#
# Pain.
#
# is coursing through my fingertips.
#
# I start speaking the language of my young, adult people. The words abrasive against the young ears that are a short yards away.
#
# Horrid realization strikes me. This is not George. No. This is something entirely different.
#
# ![horrid realization.jfif](data:image/jpeg;base64,...)

# %% [markdown]
# I accidently tased myself.

# %%
dot = graphviz.Graph(comment='The Taser Story')
dot.node('A', 'Aby The Child')
dot.node('B', 'Girl Scouts')
dot.node('C', 'Leader and Home Owner')
dot.node('I', 'Mom')
dot.node('D', 'Storm Shelter')
dot.node('E', 'Tornado')
dot.node('F', 'Dark')
dot.node('G', 'Taser')
dot.node('H', 'Poker')
dot.node('J', 'Christmas')


dot.edges(['AB', 'BC', 'IC', 'CD', 'DE', 'AF', 'DF', 'JH', 'HG', 'HI', 'IG', 'GE'])
dot

# %% [markdown]
# ### All The Answers.

# %% [markdown]
# This is Hamiltonian Cycle. Each node is able to be visited once in a closed loop.
#
# This is not a Eulcian Circuit. I have odd numbered vertices.
#
# While my story walked you though many paths.. a quick one to recap is: Aby>GirlScouts>Leader/HomeOwner>StormShelter>Tornado>Taser.
#
# To discuss a particular Vertices' degree: 'Aby The Child' has 2 degrees.
#
# I have told my story, but as for findings, I really enjoyed playing around with the creating of the graph and seeing how working in Google Colab situated the different vertices and paths.
#
# The last finding..
#
# George was never caught and is ***still*** out there. Be safe, friends.
