# %% [markdown]
# <a href="https://colab.research.google.com/github/CaseyMayo/Discrete_Math/blob/master/MayoCasey_DiscreteMathematics_Module2_Project_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part #2 : CPSMA 3133 Discrete Mathematics
#
# ## Relations and Functions
#
# ### Casey Mayo Attempt 1

# %% [markdown]
# ## 1 Functions

# %% [markdown]
# To Define, or Not To Define.... That is the question.
#
# *Just Kidding. I like making good grades.*
#
# So how exactly does one define a function? What function should I define?
#
# ![Mind Blown Emoji.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# I am defining a function with at least three features.
#
# $$
# f(x) = (2x-3)2
# $$
#
# 2x = one feature
#
# -3 = two feature
#
# ()2 = three feature  .....?

# %% [markdown]
# Since ***MATH*** is a hard one to use, I am going to import the two common packages that the Insturctor uses to make sure I am off on the right foot.

# %%
import math
import numpy as np




def cefunt(x): #cefunt for... Casey Easy Function. I know I left out a 'C' but I kind of like it better that way. 
  return ((2*x)-3)*(2)

# %% [markdown]
# Per the sample assignment... let's see if this works!

# %%
cefunt(1)
# Out:
# -2

# %% [markdown]
# Side note to myself: We will call the above using ***cefunt()***!
#
# I've already added the second package to help me plot. I am going to change the domain numbers to help me find the *sweet spot*.

# %%
x = np.arange(-100,100,.1) #I already explained the -4 and 4 but the .1 needs to be there and should just stay .1

plt.plot(x,cefunt(x))

# %% [markdown]
# ### 2 Dictionaries

# %% [markdown]
# I am going to define a dictionary that creates a relationship between set $A$ and $B$.

# %%
FriendAttributes = ['Loyal', 'Funny', 'Caring', 'Open', 'Smart', 'HasJob', 'HasKids', 'Honest', 'TrustWorthy', "kind"]
PartnerAttributes = ['Smart', 'Faithful', 'LikeMinded', 'HasCar', 'HasHouse', 'Funny', 'Dependable', 'Confident', 'LikesAnimals', 'kind']

dictionary = dict({FriendAttributes:PartnerAttributes for FriendAttributes,PartnerAttributes in zip(FriendAttributes, PartnerAttributes)})

# %%
dictionary
# Out:
# {'Loyal': 'Smart',
#  'Funny': 'Faithful',
#  'Caring': 'LikeMinded',
#  'Open': 'HasCar',
#  'Smart': 'HasHouse',
#  'HasJob': 'Funny',
#  'HasKids': 'Dependable',
#  'Honest': 'Confident',
#  'TrustWorthy': 'LikesAnimals',
#  'kind': 'kind'}

# %% [markdown]
# Imaging my dictionary as an endo relation has proven difficult. It acts upon both sets. The above would be considered anti-symmetric.
#
# Fun fact, there are a possible 1,267,650,600,228,229,401,496,703,205,376 relations. I can tell this by FriendAttributes (10) multiplied by PartnerAttributes (10) equallying one hundred. I take the set amount (2) and bring it to the power of ***one hundred***.

# %% [markdown]
# This is the quick way the Instructor showed us. I started it like this to get a better grasp on what I was doing.

# %%
actualDictionary = dict({'TrustWorthy':'Loyal','HasJob':'HasHouse', 'Loyal':'Dependable'})

# %% [markdown]
# I've added pairs to change things up a little bit. Originally, I took an element from the FriendAttributes and paired it with a similiar PartnerAttribute to give myself a little like minded idea.
#
# I didn't like the results I was getting.
#
# So I really tried to change what would be listed out when I asked for a new FriendsAttribute list and gathered what's below.

# %%
Newlist2 = [actualDictionary.get(x,x) for x in FriendAttributes]

# %%
Newlist2
# Out:
# ['Dependable',
#  'Funny',
#  'Caring',
#  'Open',
#  'Smart',
#  'HasHouse',
#  'HasKids',
#  'Honest',
#  'Loyal',
#  'kind']

# %% [markdown]
# It is not onto so not bi-jective.  In order to make my dictionary bijective, I would need my lists to be both injective and surjective. If I changed the domain, I believe I could change enough to make it bujective by changing it to guarantee that no 'x' will map to two different 'y's (and vice versa) and to make sure the range reaches every element of the co-domain so all values are taken.

# %% [markdown]
# I really like the idea of putting all attributes into a program and randomly drawing out what a single person should look for.
#
# Like a computer generated fortune teller.
#
# Careful now, Tinder. I think I've just created a better match. ;)
